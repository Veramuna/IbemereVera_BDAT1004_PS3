# %% [markdown]
# # Question 1
# ## Occupation

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users = pd.read_csv(url, sep='|')

# Step 3: Assign it to a variable called users
print(users.head())  # Display the first few rows to verify the data# Calculate mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()
print("Mean age per occupation:")
print(mean_age_per_occupation)

# Male ratio function
def male_ratio(group):
    male_count = group[group['gender'] == 'M'].shape[0]
    total_count = group.shape[0]
    return (male_count / total_count) * 100

# Calculate male ratio per occupation
male_ratio_per_occupation = (
    users.groupby('occupation')
    .apply(male_ratio, include_groups=False)  # Exclude grouping columns
    .sort_values(ascending=False)
)

print("\nMale ratio per occupation (sorted):")
print(male_ratio_per_occupation)

# Calculate min and max ages per occupation
min_max_age_per_occupation = users.groupby('occupation')['age'].agg(['min', 'max'])
print("\nMinimum and maximum ages per occupation:")
print(min_max_age_per_occupation)

# Calculate mean age per occupation and gender
mean_age_per_occupation_gender = (
    users.groupby(['occupation', 'gender'])['age'].mean()
)
print("\nMean age per occupation and gender:")
print(mean_age_per_occupation_gender)

# Function to calculate gender percentage
def gender_percentage(group):
    return group['gender'].value_counts(normalize=True) * 100

# Calculate gender percentage per occupation
gender_percentage_per_occupation = (
    users.groupby('occupation')['gender']
    .apply(lambda x: x.value_counts(normalize=True) * 100)
    .unstack(fill_value=0)  # Pivot the result into a DataFrame
)

print("\nGender percentage per occupation:")
print(gender_percentage_per_occupation)
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213
# Mean age per occupation:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64
#
# Male ratio per occupation (sorted):
# ...

# %% [markdown]
# # Question 2
# ## Euro Teams

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
euro12 = pd.read_csv(url)

# Step 3: Assign it to a variable called euro12
print(euro12.head())  # Display the first few rows to verify the dataset

# Step 4: Select only the Goal column
goals = euro12['Goals']
print("\nGoals column:")
print(goals)

# Step 5: How many teams participated in Euro 2012?
num_teams = euro12['Team'].nunique()
print(f"\nNumber of teams that participated in Euro 2012: {num_teams}")

# Step 6: What is the number of columns in the dataset?
num_columns = euro12.shape[1]
print(f"\nNumber of columns in the dataset: {num_columns}")

# Step 7: View only the columns Team, Yellow Cards, and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
print("\nDiscipline DataFrame:")
print(discipline)

# Step 8: Sort the teams by Red Cards, then by Yellow Cards
sorted_discipline = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=[False, False])
print("\nTeams sorted by Red Cards and Yellow Cards:")
print(sorted_discipline)

# Step 9: Calculate the mean Yellow Cards given per Team
mean_yellow_cards = euro12['Yellow Cards'].mean()
print(f"\nMean Yellow Cards per team: {mean_yellow_cards:.2f}")

# Step 10: Filter teams that scored more than 6 goals
teams_scored_more_than_6 = euro12[euro12['Goals'] > 6]
print("\nTeams that scored more than 6 goals:")
print(teams_scored_more_than_6)

# Step 11: Select the teams that start with G
teams_start_with_g = euro12[euro12['Team'].str.startswith('G')]
print("\nTeams that start with 'G':")
print(teams_start_with_g)

# Step 12: Select the first 7 columns
first_7_columns = euro12.iloc[:, :7]
print("\nFirst 7 columns:")
print(first_7_columns)

# Step 13: Select all columns except the last 3
all_but_last_3_columns = euro12.iloc[:, :-3]
print("\nAll columns except the last 3:")
print(all_but_last_3_columns)

# Step 14: Present only the Shooting Accuracy from England, Italy, and Russia
shooting_accuracy = euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])][['Team', 'Shooting Accuracy']]
print("\nShooting Accuracy for England, Italy, and Russia:")
print(shooting_accuracy)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# # Question 3
# ## Housing

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import numpy as np

# Step 2: Create 3 different Series
np.random.seed(42)  # Set seed for reproducibility
series1 = pd.Series(np.random.randint(1, 5, size=100))      # Random numbers from 1 to 4
series2 = pd.Series(np.random.randint(1, 4, size=100))      # Random numbers from 1 to 3
series3 = pd.Series(np.random.randint(10000, 30001, size=100))  # Random numbers from 10,000 to 30,000

# Step 3: Create a DataFrame by joining the Series by column
df = pd.concat([series1, series2, series3], axis=1)

# Step 4: Change the name of the columns
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
print("\nDataFrame with renamed columns:")
print(df.head())

# Step 5: Create a one-column DataFrame with the values of the 3 Series
bigcolumn = pd.concat([series1, series2, series3], axis=0).to_frame(name='bigcolumn')
print("\nOne-column DataFrame 'bigcolumn':")
print(bigcolumn.head(110))  # Display more rows to see beyond index 99

# Step 6: Verify if the index goes only until 99
print("\nDoes the index go only until 99?")
print(bigcolumn.index.max() == 99)

# Step 7: Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(drop=True, inplace=True)
print("\nReindexed DataFrame:")
print(bigcolumn.tail())
# Out:
# DataFrame with renamed columns:
#    bedrs  bathrs  price_sqr_meter
# 0      3       3            23931
# 1      4       2            13627
# 2      1       2            26157
# 3      3       2            20173
# 4      3       2            28047
#
# One-column DataFrame 'bigcolumn':
#     bigcolumn
# 0           3
# 1           4
# 2           1
# 3           3
# 4           3
# ..        ...
# 5           2
# 6           2
# 7           3
# 8           3
# 9           2
#
# [110 rows x 1 columns]
#
# Does the index go only until 99?
# True
#
# Reindexed DataFrame:
#      bigcolumn
# 295      11154
# 296      14499
# 297      16295
# 298      22183
# 299      22874

# %% [markdown]
# # QUESTION 4
# ## wind Statistics

# %%
import pandas as pd
import numpy as np

file_path = file_path = r'C:\Users\General-User\Downloads\wind (2).txt'
 
data = pd.read_csv(file_path, sep=r'\s+', header=0)

data['Date'] = pd.to_datetime(data[['Yr', 'Mo', 'Dy']].astype(str).agg('-'.join, axis=1), format='%y-%m-%d')
data.drop(['Yr', 'Mo', 'Dy'], axis=1, inplace=True)
data.set_index('Date', inplace=True)

def correct_year(date):
    return date.replace(year=date.year - 100) if date.year > 2000 else date

data.index = data.index.map(correct_year)

assert data.index.dtype == 'datetime64[ns]'

missing_values = data.isnull().sum()

non_missing_total = data.notnull().sum().sum()

overall_mean_windspeed = data.mean().mean()

loc_stats = data.describe().transpose()[['min', 'max', 'mean', 'std']]

day_stats = data.aggregate(['min', 'max', 'mean', 'std'], axis=1)

january_data = data[data.index.month == 1]
january_avg_windspeed = january_data.groupby(january_data.index.month).mean()

yearly_data = data.resample('YE').mean()

monthly_data = data.resample('ME').mean()

weekly_data = data.resample('W').mean()

weekly_stats = weekly_data.aggregate(['min', 'max', 'mean', 'std']).iloc[:52]

print("\nMissing Values by Location:")
print(missing_values)

print("\nTotal Non-Missing Values:")
print(non_missing_total)

print("\nOverall Mean Windspeed:")
print(overall_mean_windspeed)

print("\nLocation Statistics:")
print(loc_stats)

print("\nDaily Statistics:")
print(day_stats)

print("\nJanuary Average Windspeed:")
print(january_avg_windspeed)

print("\nYearly Data:")
print(yearly_data)

print("\nMonthly Data:")
print(monthly_data)

print("\nWeekly Data:")
print(weekly_data)

print("\nWeekly Statistics for First 52 Weeks:")
print(weekly_stats)
# Out:
# Missing Values by Location:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64
#
# Total Non-Missing Values:
# 78857
#
# Overall Mean Windspeed:
# 10.227982360836938
#
# Location Statistics:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794
#
# Daily Statistics:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# ...

# %% [markdown]
# # Question 5

# %%
# Step 1: Import the necessary libraries
import pandas as pd

# Step 2: Import the dataset
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep='\t')

# Step 3: Assign it to a variable called chipo
# (Already done above)

# Step 4: See the first 10 entries
print("First 10 entries:")
print(chipo.head(10))

# Step 5: What is the number of observations in the dataset?
num_observations = chipo.shape[0]
print("\nNumber of observations:", num_observations)

# Step 6: What is the number of columns in the dataset?
num_columns = chipo.shape[1]
print("\nNumber of columns:", num_columns)

# Step 7: Print the name of all the columns.
print("\nColumn names:")
print(chipo.columns)

# Step 8: How is the dataset indexed?
print("\nDataset indexing:")
print(chipo.index)

# Step 9: Which was the most-ordered item?
most_ordered_item = chipo.groupby('item_name').sum().sort_values('quantity', ascending=False).head(1)
print("\nMost-ordered item:")
print(most_ordered_item)

# Step 10: For the most-ordered item, how many items were ordered?
most_ordered_quantity = most_ordered_item['quantity'].values[0]
print("\nQuantity of most-ordered item:", most_ordered_quantity)

# Step 11: What was the most ordered item in the choice_description column?
most_ordered_choice = chipo['choice_description'].value_counts().idxmax()
print("\nMost-ordered choice description:", most_ordered_choice)

# Step 12: How many items were ordered in total?
total_items_ordered = chipo['quantity'].sum()
print("\nTotal items ordered:", total_items_ordered)

# Step 13: Turn the item price into a float
# Remove the dollar sign and convert to float
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)

# Verify the type
print("\nItem price type after conversion:", chipo['item_price'].dtype)

# Step 14: How much was the revenue for the period in the dataset?
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print("\nTotal revenue:", revenue)

# Step 15: How many orders were made in the period?
total_orders = chipo['order_id'].nunique()
print("\nTotal orders:", total_orders)

# Step 16: What is the average revenue amount per order?
avg_revenue_per_order = revenue / total_orders
print("\nAverage revenue per order:", avg_revenue_per_order)

# Step 17: How many different items are sold?
unique_items_sold = chipo['item_name'].nunique()
print("\nNumber of different items sold:", unique_items_sold)
# Out:
# First 10 entries:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# # Question 6
# ## Create a line plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = r'C:\Users\General-User\Documents\Data Analysis\Data Analytic Programming\problem set 3_files\us-marriages-divorces-1867-2014.csv'

us_marriages_divorces = pd.read_csv(file_path)

# Create the line plot for marriages and divorces per capita
plt.figure(figsize=(12, 6))
plt.plot(us_marriages_divorces['Year'], us_marriages_divorces['Marriages_per_1000'], label='Marriages per 1000', color='blue', linewidth=2)
plt.plot(us_marriages_divorces['Year'], us_marriages_divorces['Divorces_per_1000'], label='Divorces per 1000', color='red', linewidth=2)

# Add labels, title, and legend
plt.title('Marriages and Divorces per Capita in the U.S. (1867-2014)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number per 1000 People', fontsize=12)
plt.legend()
plt.grid(alpha=0.5)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 7
# ## A vertical bar chart for comparism

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = r'C:\Users\General-User\Documents\Data Analysis\Data Analytic Programming\problem set 3_files\us-marriages-divorces-1867-2014.csv'
data = pd.read_csv(file_path)

# Filter the data for the years 1900, 1950, and 2000
filtered_data = data[data['Year'].isin([1900, 1950, 2000])]

# Plot the bar chart
x = ['1900', '1950', '2000']
marriages = filtered_data['Marriages_per_1000']
divorces = filtered_data['Divorces_per_1000']

bar_width = 0.35
positions = range(len(x))

plt.bar(positions, marriages, width=bar_width, label='Marriages per 1000', color='blue')
plt.bar([p + bar_width for p in positions], divorces, width=bar_width, label='Divorces per 1000', color='red')

# Add labels, legend, and title
plt.xlabel('Year')
plt.ylabel('Number per 1000 people')
plt.title('Marriages and Divorces per Capita in the U.S. (1900, 1950, 2000)')
plt.xticks([p + bar_width / 2 for p in positions], x)
plt.legend()

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 8
# ## A horizontal bar chart that compares the deadliest actors in Hollywood.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = r'C:\Users\General-User\Documents\Data Analysis\Data Analytic Programming\problem set 3_files\actor_kill_counts.csv'
actor_data = pd.read_csv(file_path)

# Sort the data by the kill count
actor_data_sorted = actor_data.sort_values(by=['Actor', 'Count'], ascending=[True, False])

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(actor_data_sorted['Actor'], actor_data_sorted['Count'], color='darkred')


# Add labels, title, and grid
plt.xlabel('Kill Count') 
plt.ylabel('Actor')      

plt.title('Deadliest Actors in Hollywood by Kill Count')
plt.gca().invert_yaxis()  
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 9
# ## A pie chart showing the fraction of all Roman Emperors that were assassinated.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
file_path = r'C:\Users\General-User\Documents\Data Analysis\Data Analytic Programming\problem set 3_files\roman-emperor-reigns.csv'
emperor_data = pd.read_csv(file_path)

# Extract the emperors that were assassinated
assassinated_emperors = emperor_data[emperor_data['Cause_of_Death'].str.contains('assassinated', case=False, na=False)]

# Show the names of all emperors who were assassinated
print("Roman Emperors Assassinated:")
print(assassinated_emperors['Emperor'].tolist())

# Count categories: Assassinated vs Not Assassinated
assassination_counts = emperor_data['Cause_of_Death'].apply(lambda x: 'Assassinated' if 'assassinated' in str(x).lower() else 'Other').value_counts()

# Define a function to show both counts and percentages in the pie chart
def autopct_details(pct, all_values):
    count = int(round(pct / 100.0 * sum(all_values)))
    return f'{pct:.1f}%\n({count})'

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(
    assassination_counts, 
    labels=assassination_counts.index, 
    autopct=lambda pct: autopct_details(pct, assassination_counts), 
    startangle=90, 
    colors=['crimson', 'gray'], 
    wedgeprops={'edgecolor': 'black'}
)

# Add a title
plt.title('Fraction of Roman Emperors Assassinated')
plt.tight_layout()

# Display the pie chart
plt.show()
# Out:
# Roman Emperors Assassinated:
# ['Augustus', 'Tiberius', 'Caligula', 'Claudius', 'Galba', 'Vitellius', 'Domitian', 'Commodus', 'Pertinax', 'Caracalla', 'Geta', 'Elagabalus', 'Severus Alexander', 'Maximinus I', 'Pupienus', 'Balbinus', 'Gordian III', 'Trebonianus Gallus', 'Aemilian', 'Gallienus', 'Quintillus', 'Aurelian', 'Tacitus', 'Florian', 'Probus', 'Numerian', 'Severus II', 'Constans I', 'Gratian', 'Valentinian II']

# %% [markdown]
# # Question 10
# ## A scatter plot showing the relationships.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
arcade_data_path = r'C:\Users\General-User\Documents\Data Analysis\Data Analytic Programming\problem set 3_files\arcade-revenue-vs-cs-doctorates.csv'
arcade_data = pd.read_csv(arcade_data_path)

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    arcade_data['Total Arcade Revenue (billions)'], 
    arcade_data['Computer Science Doctorates Awarded (US)'], 
    c=arcade_data['Year'], 
    cmap='viridis', 
    s=100, 
    edgecolor='black'
)

# Add colorbar to show the year scale
plt.colorbar(scatter, label='Year')

# Add labels and title
plt.xlabel('Total Revenue Earned by Arcades (in billions)')
plt.ylabel('Number of PhDs Awarded in Computer Science')
plt.title('Relationship Between Arcade Revenue and PhDs Awarded (2000-2009)')

# Show the plot
plt.tight_layout()
plt.show()
